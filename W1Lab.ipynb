# %% [markdown]
# #Digging Through Data

# %% [markdown]
# ##### In this week's lab, we are going to utilize the following python libraries:
# <br>
# <li> <b>Numpy</b> is a library for working with arrays of data.</li>
# <li> <b>Scipy</b> is a library of techniques for numerical and scientific computing.</li>
# <li> <b>Matplotlib</b> is a library for making visualizations. </li>
# <li> <b>Seaborn</b> is a higher-level interface to Matplotlib that can be used to simplify many visualization tasks </li>
# <li> <b>Pandas</b> is a library for data manipulation and analysis.</li>
#
# ##### Important: While this lab notebook provides insight into the basics of these libraries, I recommend digging into the documentation that is available online.
#
# ###  Import the necessary libraries

# %% [markdown]
# ### Mount the Google Drive and Load the dataset for the data folder

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Assign it to a variable called chipo.

# %% [markdown]
# ###  See the first 10 entries

# %% [markdown]
# ### What is the number of observations in the dataset?

# %%
# Solution 1

# %%
# Solution 2

# %% [markdown]
# ###  What is the number of columns in the dataset?

# %% [markdown]
# ### Print the name of all the columns.

# %% [markdown]
# ###  Which was the most-ordered item? Can we add some variations to this?

# %% [markdown]
# ###  What was the most ordered item in the choice_description column?

# %% [markdown]
# ### How many items were orderd in total?

# %% [markdown]
# ###  Turn the item price into a float

# %% [markdown]
# -  Check the item price type
# -  Create a lambda function and change the type of item price
# -  Check the item price type again

# %% [markdown]
# ### How much was the revenue for the period in the dataset?

# %% [markdown]
# ### How many orders were made in the period?

# %% [markdown]
# ### What is the average revenue amount per order?

# %%
# Solution 1

# %%
# Solution 2

# %% [markdown]
#  ### How many different items are sold?

# %% [markdown]
#  ### Create a histogram of the top 5 items bought

# %% [markdown]
# #### Create a scatterplot with the number of items orderered per order price

# %% [markdown]
# # Homework - If time permits
#
# Write code to answer these Questions:
#
# *   How many products cost more than $10.00?
#
# *
